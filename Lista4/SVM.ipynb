# %% [markdown]
# # 4ª Lista de Aprendizado de Máquina
# ## Support Vector Machine
#
# Aluno: | Hugo Silva de Vasconcelos
# ----|----
# Matrícula: | 180102028
# Dataset: | [Breast Cancer Wisconsin Diagnostic Dataset](https://www.kaggle.com/datasets/utkarshx27/breast-cancer-wisconsin-diagnostic-dataset?resource=download)

# %% [markdown]
# ## Análise Exploratória

# %%
import pandas as pd

df = pd.read_csv('brca.csv', index_col=0)
df.head(10)
# Out:
#     x.radius_mean  x.texture_mean  x.perimeter_mean  x.area_mean  \
# 1          13.540           14.36             87.46        566.3
# 2          13.080           15.71             85.63        520.0
# 3           9.504           12.44             60.34        273.9
# 4          13.030           18.42             82.61        523.8
# 5           8.196           16.84             51.71        201.9
# 6          12.050           14.63             78.04        449.3
# 7          13.490           22.30             86.91        561.0
# 8          11.760           21.60             74.72        427.9
# 9          13.640           16.34             87.21        571.8
# 10         11.940           18.24             75.71        437.6
#
#     x.smoothness_mean  x.compactness_mean  x.concavity_mean  \
# 1             0.09779             0.08129           0.06664
# 2             0.10750             0.12700           0.04568
# 3             0.10240             0.06492           0.02956
# 4             0.08983             0.03766           0.02562
# 5             0.08600             0.05943           0.01588
# 6             0.10310             0.09092           0.06592
# 7             0.08752             0.07698           0.04751
# 8             0.08637             0.04966           0.01657
# 9             0.07685             0.06059           0.01857
# 10            0.08261             0.04751           0.01972
#
#     x.concave_pts_mean  x.symmetry_mean  x.fractal_dim_mean  ...  \
# 1             0.047810           0.1885             0.05766  ...
# 2             0.031100           0.1967             0.06811  ...
# 3             0.020760           0.1815             0.06905  ...
# 4             0.029230           0.1467             0.05863  ...
# 5             0.005917           0.1769             0.06503  ...
# 6             0.027490           0.1675             0.06043  ...
# 7             0.033840           0.1809             0.05718  ...
# 8             0.011150           0.1495             0.05888  ...
# 9             0.017230           0.1353             0.05953  ...
# 10            0.013490           0.1868             0.06110  ...
#
#     x.texture_worst  x.perimeter_worst  x.area_worst  x.smoothness_worst  \
# 1             19.26              99.70         711.2             0.14400
# 2             20.49              96.09         630.5             0.13120
# 3             15.66              65.13         314.9             0.13240
# 4             22.81              84.46         545.9             0.09701
# 5             21.96              57.26         242.2             0.12970
# 6             20.70              89.88         582.6             0.14940
# 7             31.82              99.00         698.8             0.11620
# 8             25.72              82.98         516.5             0.10850
# 9             23.19              96.08         656.7             0.10890
# 10            21.33              83.67         527.2             0.11440
#
#     x.compactness_worst  x.concavity_worst  x.concave_pts_worst  \
# 1               0.17730            0.23900              0.12880
# 2               0.27760            0.18900              0.07283
# 3               0.11480            0.08867              0.06227
# 4               0.04619            0.04833              0.05013
# 5               0.13570            0.06880              0.02564
# 6               0.21560            0.30500              0.06548
# 7               0.17110            0.22820              0.12820
# 8               0.08615            0.05523              0.03715
# 9               0.15820            0.10500              0.08586
# 10              0.08906            0.09203              0.06296
#
#     x.symmetry_worst  x.fractal_dim_worst  y
# 1             0.2977              0.07259  B
# 2             0.3184              0.08183  B
# 3             0.2450              0.07773  B
# 4             0.1987              0.06169  B
# 5             0.3105              0.07409  B
# 6             0.2747              0.08301  B
# 7             0.2871              0.06917  B
# 8             0.2433              0.06563  B
# 9             0.2346              0.08025  B
# 10            0.2785              0.07408  B
#
# [10 rows x 31 columns]

# %%
df.shape
# Out:
# (569, 31)

# %%
df.describe()
# Out:
#        x.radius_mean  x.texture_mean  x.perimeter_mean  x.area_mean  \
# count     569.000000      569.000000        569.000000   569.000000
# mean       14.127292       19.289649         91.969033   654.889104
# std         3.524049        4.301036         24.298981   351.914129
# min         6.981000        9.710000         43.790000   143.500000
# 25%        11.700000       16.170000         75.170000   420.300000
# 50%        13.370000       18.840000         86.240000   551.100000
# 75%        15.780000       21.800000        104.100000   782.700000
# max        28.110000       39.280000        188.500000  2501.000000
#
#        x.smoothness_mean  x.compactness_mean  x.concavity_mean  \
# count         569.000000          569.000000        569.000000
# mean            0.096360            0.104341          0.088799
# std             0.014064            0.052813          0.079720
# min             0.052630            0.019380          0.000000
# 25%             0.086370            0.064920          0.029560
# 50%             0.095870            0.092630          0.061540
# 75%             0.105300            0.130400          0.130700
# max             0.163400            0.345400          0.426800
#
#        x.concave_pts_mean  x.symmetry_mean  x.fractal_dim_mean  ...  \
# count          569.000000       569.000000          569.000000  ...
# mean             0.048919         0.181162            0.062798  ...
# std              0.038803         0.027414            0.007060  ...
# min              0.000000         0.106000            0.049960  ...
# 25%              0.020310         0.161900            0.057700  ...
# 50%              0.033500         0.179200            0.061540  ...
# 75%              0.074000         0.195700            0.066120  ...
# max              0.201200         0.304000            0.097440  ...
#
#        x.radius_worst  x.texture_worst  x.perimeter_worst  x.area_worst  \
# count      569.000000       569.000000         569.000000    569.000000
# mean        16.269190        25.677223         107.261213    880.583128
# std          4.833242         6.146258          33.602542    569.356993
# min          7.930000        12.020000          50.410000    185.200000
# 25%         13.010000        21.080000          84.110000    515.300000
# 50%         14.970000        25.410000          97.660000    686.500000
# 75%         18.790000        29.720000         125.400000   1084.000000
# max         36.040000        49.540000         251.200000   4254.000000
#
#        x.smoothness_worst  x.compactness_worst  x.concavity_worst  \
# count          569.000000           569.000000         569.000000
# mean             0.132369             0.254265           0.272188
# std              0.022832             0.157336           0.208624
# min              0.071170             0.027290           0.000000
# 25%              0.116600             0.147200           0.114500
# 50%              0.131300             0.211900           0.226700
# 75%              0.146000             0.339100           0.382900
# max              0.222600             1.058000           1.252000
#
#        x.concave_pts_worst  x.symmetry_worst  x.fractal_dim_worst
# count           569.000000        569.000000           569.000000
# mean              0.114606          0.290076             0.083946
# std               0.065732          0.061867             0.018061
# min               0.000000          0.156500             0.055040
# 25%               0.064930          0.250400             0.071460
# 50%               0.099930          0.282200             0.080040
# 75%               0.161400          0.317900             0.092080
# max               0.291000          0.663800             0.207500
#
# [8 rows x 30 columns]

# %% [markdown]
# ## Separando o dataset em dados e classe

# %%
X = df.drop('y', axis=1)
y = df.y

# %% [markdown]
# ## Normalizando os dados

# %%
def normaliza(column):
    mean = column.mean()
    std = column.std()
    return (column - mean) / std

# %%
for column in X.columns:
    X[column] = normaliza(X[column])

# %%
X.describe()
# Out:
#        x.radius_mean  x.texture_mean  x.perimeter_mean   x.area_mean  \
# count   5.690000e+02    5.690000e+02      5.690000e+02  5.690000e+02
# mean   -1.498508e-16   -7.742293e-16     -1.498508e-16 -1.998011e-16
# std     1.000000e+00    1.000000e+00      1.000000e+00  1.000000e+00
# min    -2.027864e+00   -2.227289e+00     -1.982759e+00 -1.453164e+00
# 25%    -6.887793e-01   -7.253249e-01     -6.913472e-01 -6.666089e-01
# 50%    -2.148925e-01   -1.045442e-01     -2.357726e-01 -2.949274e-01
# 75%     4.689800e-01    5.836621e-01      4.992377e-01  3.631877e-01
# max     3.967796e+00    4.647799e+00      3.972634e+00  5.245913e+00
#
#        x.smoothness_mean  x.compactness_mean  x.concavity_mean  \
# count       5.690000e+02        5.690000e+02      5.690000e+02
# mean        1.748260e-16        1.998011e-16      9.990056e-17
# std         1.000000e+00        1.000000e+00      1.000000e+00
# min        -3.109349e+00       -1.608721e+00     -1.113893e+00
# 25%        -7.103378e-01       -7.464292e-01     -7.430941e-01
# 50%        -3.486040e-02       -2.217454e-01     -3.419391e-01
# 75%         6.356397e-01        4.934227e-01      5.255994e-01
# max         4.766717e+00        4.564409e+00      4.239858e+00
#
#        x.concave_pts_mean  x.symmetry_mean  x.fractal_dim_mean  ...  \
# count        5.690000e+02     5.690000e+02        5.690000e+02  ...
# mean         1.498508e-16     1.748260e-16        4.682839e-16  ...
# std          1.000000e+00     1.000000e+00        1.000000e+00  ...
# min         -1.260710e+00    -2.741705e+00       -1.818265e+00  ...
# 25%         -7.372951e-01    -7.026215e-01       -7.220040e-01  ...
# 50%         -3.973715e-01    -7.156354e-02       -1.781226e-01  ...
# 75%          6.463664e-01     5.303125e-01        4.705693e-01  ...
# max          3.924477e+00     4.480808e+00        4.906602e+00  ...
#
#        x.radius_worst  x.texture_worst  x.perimeter_worst  x.area_worst  \
# count    5.690000e+02     5.690000e+02       5.690000e+02  5.690000e+02
# mean    -4.995028e-17     2.497514e-17       4.995028e-17 -2.497514e-16
# std      1.000000e+00     1.000000e+00       1.000000e+00  1.000000e+00
# min     -1.725382e+00    -2.222039e+00      -1.691872e+00 -1.221348e+00
# 25%     -6.743279e-01    -7.479711e-01      -6.889721e-01 -6.415713e-01
# 50%     -2.688030e-01    -4.347738e-02      -2.857288e-01 -3.408813e-01
# 75%      5.215568e-01     6.577623e-01       5.398040e-01  3.572747e-01
# max      4.090590e+00     3.882489e+00       4.283568e+00  5.924959e+00
#
#        x.smoothness_worst  x.compactness_worst  x.concavity_worst  \
# count        5.690000e+02         5.690000e+02       5.690000e+02
# mean        -1.448558e-15        -4.995028e-17       4.995028e-17
# std          1.000000e+00         1.000000e+00       1.000000e+00
# min         -2.680337e+00        -1.442609e+00      -1.304683e+00
# 25%         -6.906227e-01        -6.804845e-01      -7.558491e-01
# 50%         -4.680159e-02        -2.692639e-01      -2.180402e-01
# 75%          5.970195e-01         5.391944e-01       5.306742e-01
# max          3.951897e+00         5.108382e+00       4.696536e+00
#
#        x.concave_pts_worst  x.symmetry_worst  x.fractal_dim_worst
# count         5.690000e+02      5.690000e+02         5.690000e+02
# mean          1.998011e-16      2.747265e-16         1.748260e-16
# std           1.000000e+00      1.000000e+00         1.000000e+00
# min          -1.743529e+00     -2.159060e+00        -1.600431e+00
# 25%          -7.557349e-01     -6.412994e-01        -6.913035e-01
# 50%          -2.232725e-01     -1.272975e-01        -2.162538e-01
# 75%           7.118836e-01      4.497425e-01         4.503661e-01
# max           2.683516e+00      6.040726e+00         6.840837e+00
#
# [8 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# SVM
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

svm = SVC(kernel='linear')
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.958041958041958

# %%
# SVM com kernel RBF
svm = SVC(kernel='rbf')
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.958041958041958

# %%
# SVM com kernel polinomial
svm = SVC(kernel='poly')
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9020979020979021

# %%
# SVM com kernel sigmoid
svm = SVC(kernel='sigmoid')
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9440559440559441

# %%
# SVM com kernel linear e C=0.1
svm = SVC(kernel='linear', C=0.1)
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.972027972027972
